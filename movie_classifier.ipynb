# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ASUS\Documents\ml pojects\Movie_classification.csv")

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# # Missing value imputation

# %%
df['Time_taken'].mean()
# Out:
# 157.3914979757085

# %%
df['Time_taken'].fillna(value = df['Time_taken'].mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22792\1486983121.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Time_taken'].fillna(value = df['Time_taken'].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# # Dummy varible creation

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df = pd.get_dummies(df, columns = ["3D_available", "Genre"], drop_first = True , dtype = int)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  ...  Time_taken  Twitter_hastags  \
# ...

# %% [markdown]
# # X - y split

# %%
X = df.loc[:, df.columns != "Start_Tech_Oscar"]
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
X.shape
# Out:
# (506, 20)

# %%
y = df["Start_Tech_Oscar"]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Start_Tech_Oscar, dtype: int64

# %%
y.shape
# Out:
# (506,)

# %% [markdown]
# # test-train split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size = 0.2)

# %%
X_train.head()
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 139            30.8904               98.78               0.376  34168.805
# 29             40.0490               71.28               0.462  37074.070
# 128            26.5086               98.78               0.376  35724.205
# 504            22.1918               78.86               0.427  37740.670
# 386           507.8760               91.20               0.300  25841.860
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 139         171.4               9.045                9.205             9.16
# 29          160.8               7.735                8.030             7.82
# 128         172.3               9.020                9.195             9.04
# 504         162.8               8.730                8.845             8.80
# 386         173.5               9.145                9.320             9.14
#
# ...

# %%
X_train.shape
# Out:
# (404, 20)

# %%
X_test.shape
# Out:
# (102, 20)

# %% [markdown]
# # training classification

# %%
from sklearn import tree
clftree = tree.DecisionTreeClassifier(max_depth=3)

# %%
clftree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# # predict values using trained model

# %%
y_train_pred = clftree.predict(X_train)
y_test_pred = clftree.predict(X_test)

# %% [markdown]
# # model performance

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
confusion_matrix(y_train,y_train_pred)
# Out:
# array([[189,   2],
#        [143,  70]], dtype=int64)

# %%
confusion_matrix(y_test,y_test_pred)
# Out:
# array([[36,  3],
#        [50, 13]], dtype=int64)

# %%
accuracy_score(y_test,y_test_pred)
# Out:
# 0.4803921568627451

# %% [markdown]
# # plotting

# %%
dot_data = tree.export_graphviz(clftree, out_file=None,feature_names= X_train.columns, filled = True)

# %%
from IPython.display import Image

# %%
import pydotplus

# %%
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[40], line 2
#       1 graph = pydotplus.graph_from_dot_data(dot_data)
# ----> 2 Image(graph.create_png())
#
# File ~\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1797, in Dot.__init__.<locals>.<lambda>(f, prog)
#    1792 # Automatically creates all the methods enabling the creation
#    1793 # of output in any of the supported formats.
#    1794 for frmt in self.formats:
#    1795     self.__setattr__(
#    1796         'create_' + frmt,
# -> 1797         lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798     )
#    1799     f = self.__dict__['create_' + frmt]
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#
# ...

# %%
conda install python-graphviz
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install python-graphviz')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:30, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
# ...

# %% [markdown]
# # bagging

# %%
clftree = tree.DecisionTreeClassifier()

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag_clf = BaggingClassifier(clftree, n_estimators=1000, bootstrap =True, n_jobs= -1, random_state=42 )

# %%
bag_clf.fit(X_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=1000,
#                   n_jobs=-1, random_state=42)

# %%
confusion_matrix(y_test, bag_clf.predict(X_test))
# Out:
# array([[21, 18],
#        [27, 36]], dtype=int64)

# %%
accuracy_score(y_test, bag_clf.predict(X_test))
# Out:
# 0.5588235294117647

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier(n_estimators=1000,n_jobs = -1, random_state = 42 )

# %%
rf_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=42)

# %%
confusion_matrix(y_test,rf_clf.predict(X_test))
# Out:
# array([[21, 18],
#        [26, 37]], dtype=int64)

# %%
accuracy_score(y_test,rf_clf.predict(X_test))
# Out:
# 0.5686274509803921

# %% [markdown]
# # grid search

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf_clf = RandomForestClassifier(n_estimators=250, random_state = 42 )

# %%
params_grid = {
    "max_features" : [4,5,6,7,8,9,10],
    "min_samples_split" : [2,3,10]
}

# %%
grid_search = GridSearchCV(rf_clf, params_grid, n_jobs=-1,cv =5 ,scoring = "accuracy") #cv - cross validation

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(n_estimators=250,
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_features': [4, 5, 6, 7, 8, 9, 10],
#                          'min_samples_split': [2, 3, 10]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'max_features': 10, 'min_samples_split': 2}

# %%
cvrf_clf = grid_search.best_estimator_

# %%
accuracy_score(y_test , cvrf_clf.predict(X_test))
# Out:
# 0.5882352941176471

# %%
confusion_matrix(y_test , cvrf_clf.predict(X_test))
# Out:
# array([[21, 18],
#        [24, 39]], dtype=int64)
